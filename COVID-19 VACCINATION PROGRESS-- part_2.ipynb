# %%
from cs103 import *
from typing import Optional

TotalVaccinations = Optional[float]
#interp. the total vaccinations
#or None if there's no data

TV_None = None
TV1 = 0.0
TV2 = 22302
TV3 = 99.0

@typecheck
def fn_for_total_vaccinations(tv:TotalVaccinations)->...:
    #template based on One of (2 cases) and Atonic Non-Distinct 
    if tv is None:
        return ...
    else:
        return ...,(tv)

# %%
@typecheck
def total_vaccinations(tv:TotalVaccinations)->float:
    """
    enter a TotalVaccinations if it is None,return 0
    otherwise return TotalVaccinations
    """
    #return 0.0
    #template from TotalVaccinations
    if tv is None:
        return 0
    else:
        return tv
start_testing()
expect(total_vaccinations(None),0)
expect(total_vaccinations(TV2),22302)
expect(total_vaccinations(TV1),0.0)
summary()
# Out:
# 3 of 3 tests passed

# %%
PeopleVaccinated = Optional[float]
#interp. number of people vaccinated
#or None if there's no data

PV_None = None
PV1 = 0.0
PV2 = 12878.0
PV3 = 10000.0

@typecheck
def fn_for_people_vaccinated(pv:PeopleVaccinated)->...:
    #template based on One of (2 cases) and Atonic Non-Distinct 
    if pv is None:
        return ...
    else:
        return ...,(pv)

# %%
@typecheck
def people_vaccinated(pv:PeopleVaccinated)->float:
    """
    enter a PeopleVaccinated if it is None,return 0
    otherwise return PeopleVaccinated
    """
    #return 0.0
    #template from PeopleVaccinated
    if pv is None:
        return 0
    else:
        return pv
start_testing()
expect(people_vaccinated(None),0)
expect(people_vaccinated(PV2),12878)
expect(people_vaccinated(PV3),10000)
summary()
# Out:
# 3 of 3 tests passed

# %%
PeopleFullyVaccinated = Optional[float]
#interp. number of people fully vaccinated
#or None if there's no data

PFV_None = None
PFV1 = 0.0
PFV2 = 8888.0
PFV3 = 12300.0

@typecheck
def fn_for_people_fully_vaccinated(pfv:PeopleFullyVaccinated)->...:
    #template based on One of (2 cases) and Atonic Non-Distinct 
    if pfv is None:
        return ...
    else:
        return ...,(pfv)

# %%
@typecheck
def people_fully_vaccinated(pfv:PeopleFullyVaccinated)->float:
    """
    enter a PeopleFullyVaccinated if it is None,return 0
    otherwise return PeopleFullyVaccinated
    """
    #return 0.0
    #template from PeopleFullyVaccinated
    if pfv is None:
        return 0
    else:
        return pfv
start_testing()
expect(people_fully_vaccinated(None),0)
expect(people_fully_vaccinated(PFV2),8888.0)
expect(people_fully_vaccinated(PFV3),12300.0)
summary()
# Out:
# 3 of 3 tests passed

# %%
DailyVaccinationsRaw = Optional[float]
#interp. daily vaccinations raw
#or None if there's no data

DVR_None = None
DVR1 = 0.0
DVR2 = 1000.0
DVR3 = 78999.0

@typecheck
def fn_for_daily_vaccinations_raw(dvr:DailyVaccinationsRaw)->...:
    #template based on One of (2 cases) and Atonic Non-Distinct 
    if dvr is None:
        return ...
    else:
        return ...,(dvr)

# %%
@typecheck
def daily_vaccinations_raw(dvr:DailyVaccinationsRaw)->float:
    """
    enter a DailyVaccinationsRaw if it is None,return 0
    otherwise return DailyVaccinationsRaw
    """
    #return 0.0
    #template from DailyVaccinationsRaw
    if dvr is None:
        return 0
    else:
        return dvr
start_testing()
expect(daily_vaccinations_raw(None),0)
expect(daily_vaccinations_raw(DVR2),1000.0)
expect(daily_vaccinations_raw(DVR3),78999.0)
summary()
# Out:
# 3 of 3 tests passed

# %%
DailyVaccinations = Optional[float]
#interp. daily vaccinations
#or None if there's no data

DV_None = None
DV1 = 0.0
DV2 = 1234.0
DV3 = 3464.0

@typecheck
def fn_for_daily_vaccinations(dv:DailyVaccinations)->...:
    #template based on One of (2 cases) and Atonic Non-Distinct 
    if dv is None:
        return ...
    else:
        return ...,(dv)

# %%
@typecheck
def daily_vaccinations(dv:DailyVaccinations)->float:
    """
    enter a DailyVaccinations if it is None,return 0
    otherwise return DailyVaccinations
    """
    #return 0.0
    #template from DailyVaccinations
    if dv is None:
        return 0
    else:
        return dv
start_testing()
expect(daily_vaccinations(None),0)
expect(daily_vaccinations(DV2),1234.0)
expect(daily_vaccinations(DV3),3464.0)
summary()
# Out:
# 3 of 3 tests passed

# %%
TotalVaccinationsPerHundred = Optional[float]
#interp. total vaccinations per hundred
#or None if there's no data

TVPH_None = None
TVPH1 = 0.0
TVPH2 = 7879.0
TVPH3 = 33738.0

@typecheck
def fn_for_total_vaccinations_per_hundred(tvph:TotalVaccinationsPerHundred)->...:
    #template based on One of (2 cases) and Atonic Non-Distinct 
    if tvph is None:
        return ...
    else:
        return ...,(tvph)

# %%
@typecheck
def total_vaccinations_per_hundred(tvph:TotalVaccinationsPerHundred)->float:
    """
    enter a TotalVaccinationsPerHundred if it is None,return 0
    otherwise return TotalVaccinationsPerHundred
    """
    #return 0.0
    #template from TotalVaccinationsPerHundred
    if tvph is None:
        return 0
    else:
        return tvph
start_testing()
expect(total_vaccinations_per_hundred(None),0)
expect(total_vaccinations_per_hundred(TVPH2),7879.0)
expect(total_vaccinations_per_hundred(TVPH3),33738.0)
summary()
# Out:
# 3 of 3 tests passed

# %%
PeopleVaccinatedPerHundred = Optional[float]
#interp. number of people vaccinated per hundred
#or None if there's no data

PVH_None = None
PVH1 = 0.0
PVH2 = 89759.0
PVH3 = 11134.0

@typecheck
def fn_for_people_vaccinated_per_hundred(pvh:PeopleVaccinatedPerHundred)->...:
    #template based on One of (2 cases) and Atonic Non-Distinct 
    if pvh is None:
        return ...
    else:
        return ...,(pvh)

# %%
@typecheck
def people_vaccinated_per_hundred(pvh:PeopleVaccinatedPerHundred)->float:
    """
    enter a PeopleVaccinatedPerHundred if it is None,return 0
    otherwise return PeopleVaccinatedPerHundred
    """
    #return 0.0
    #template from PeopleVaccinatedPerHundred
    if pvh is None:
        return 0
    else:
        return pvh
start_testing()
expect(people_vaccinated_per_hundred(None),0)
expect(people_vaccinated_per_hundred(PVH2),89759.0)
expect(people_vaccinated_per_hundred(PVH3),11134.0)
summary()
# Out:
# 3 of 3 tests passed

# %%
PeopleFullyVaccinatedPerHundred = Optional[float]
#interp. people fully vaccinated per hundred
#or None if there's no data

PFVH_None = None
PFVH1 = 0.0
PFVH2 = 89759.0
PFVH3 = 11134.0

@typecheck
def fn_for_people_vaccinated_per_hundred(pfvh:PeopleFullyVaccinatedPerHundred)->...:
    #template based on One of (2 cases) and Atonic Non-Distinct 
    if pfvh is None:
        return ...
    else:
        return ...,(pfvh)

# %%
@typecheck
def people_fully_vaccinated_per_hundred(pfvh:PeopleFullyVaccinatedPerHundred)->float:
    """
    enter a PeopleFullyVaccinatedPerHundred if it is None,return 0
    otherwise return PeopleFullyVaccinatedPerHundred
    """
    #return 0.0
    #template from PeopleFullyVaccinatedPerHundred
    if pfvh is None:
        return 0
    else:
        return pfvh
start_testing()
expect(people_vaccinated_per_hundred(None),0)
expect(people_vaccinated_per_hundred(PFVH2),89759.0)
expect(people_vaccinated_per_hundred(PFVH3),11134.0)
summary()
# Out:
# 3 of 3 tests passed

# %%
DailyVaccinationsPerMillion = Optional[float]
#interp. daily vaccinations per million
#or None if there's no data

DVM_None = None
DVM1 = 0.0
DVM2 = 1453.0
DVM3 = 2347.0

@typecheck
def fn_for_daily_vaccinations_per_million(dvm:DailyVaccinationsPerMillion)->...:
    #template based on One of (2 cases) and Atonic Non-Distinct 
    if dvm is None:
        return ...
    else:
        return ...,(dvm)

# %%
@typecheck
def daily_vaccinations_per_million(dvm:DailyVaccinationsPerMillion)->float:
    """
    enter a DailyVaccinationsPerMillion if it is None,return 0
    otherwise return DailyVaccinationsPerMillion
    """
    #return 0.0
    #template from DailyVaccinationsPerMillion
    if dvm is None:
        return 0
    else:
        return dvm
start_testing()
expect(daily_vaccinations_per_million(None),0)
expect(daily_vaccinations_per_million(DVM2),1453.0)
expect(daily_vaccinations_per_million(DVM3),2347.0)
summary()
# Out:
# 3 of 3 tests passed

# %%
from cs103 import *
from typing import NamedTuple, List
import csv

Country = NamedTuple("Country",[('name',str),
                                ('iso_code',str),
                                ('date',str),
                                ('total_vaccinations',TotalVaccinations),
                                ('people_vaccinated',PeopleVaccinated),
                                ('people_fully_vaccinated',PeopleFullyVaccinated),
                                ('daily_vaccinations_raw',DailyVaccinationsRaw),
                                ('daily_vaccinations',DailyVaccinations),
                                ('total_vaccinations_per_hundred',TotalVaccinationsPerHundred),
                                ('people_vaccinated_per_hundred',PeopleVaccinatedPerHundred),
                                ('people_fully_vaccinated_per_hundred',PeopleFullyVaccinatedPerHundred),
                                ('daily_vaccinations_per_million',DailyVaccinationsPerMillion)])
#interp. contry's name, iso code, date, total vaccinations, people fully vaccinated, daily vaccinations raw, daily vaccinations, total vaccinations per hundred, people vaccinated per hundred, people fully vaccinated per hundred, daily vaccinations per million
Afghanistan = Country("Afghanistan","AFG","2021-07-24",1171064.0,861336.0,None,None,13476.0,3.01,2.21,None,346.0)
Andorra = Country("Andorra","AND","2021-01-25",576.0,576.0,None,None,None,0.75,0.75,None,None)
Egypt = Country("Egypt","EGY","2021-07-26",5337506.0,3697974.0,1639532.0,32805.0,21064.0,5.22,3.61,1.6,206.0)
Chad = Country("Chad","TCD","2021-07-20",None,None,None,None,660.0,None,None,None,40.0)
Chile = Country("Chile","CHL","2021-07-24",25337393.0,13772232.0,12068193.0,33269.0,81523.0,132.54,72.04,63.13,4265.0)
China = Country("China","CHN","2021-07-26",1565872000.0,None,None,15604000.0,14079429.0,108.79,None,None,9782.0)
UnitedKingdom = Country("United Kingdom","GBR","2021-07-25",83876595.0,46589211.0,37287384.0,142507.0,208976.0,123.56,68.63,54.93,3078.0)
UnitedStates = Country("United States","USA","2021-07-26",342212051.0,188729282.0,163173366.0,393083.0,566374.0,102.32,56.43,48.79,1693.0)
Zimbabwe = Country("Zimbabwe","ZWE","2021-07-25",2127402.0,1447342.0,680060.0,10738.0,48838.0,14.31,9.74,4.58,3286.0)

@typecheck
#template based on compound(12 fields)
def fn_for_country(c: Country)->...:
    return ...,(c.name,
                c.iso_code,
                c.date,
                c.total_vaccinations,
                c.people_vaccinated,
                c.people_fully_vaccinated,
                c.daily_vaccinations_raw,
                c.daily_vaccinations,
                c.total_vaccinations_per_hundred,
                c.people_vaccinated_per_hundred,
                c.people_fully_vaccinated_per_hundred,
                c.daily_vaccinations_per_million)


# List[Country]
# interp. a list of Country

LOC0 = []
LOC1 = [Afghanistan,Andorra,Egypt]
LOC2 = [Chad,Chile]
LOC3 = [China,UnitedKingdom,UnitedStates,Zimbabwe]

@typecheck
#template based on arbitrary-sized, and the reference rule
def fn_for_loc(loc: List[Country]) -> ...:
    #description for accumulator
    acc = ... #type:...
    for c in loc:
        acc = ...,(fn_for_country(c),acc)
    return ...,(acc)

# %% [markdown]
# # Read Function

# %%
@typecheck
def read(filename: str) -> List[Country]:
    """    
    reads information from the specified file and returns a list of Country
    """
    #return [] 
    # Template from HtDAP
    # loc contains the result so far
    loc = [] # type: List[Country]

    with open(filename) as csvfile:
        
        reader = csv.reader(csvfile)
        next(reader)

        for row in reader:
            c = Country(row[0],row[1],row[2],parse_float(row[3]),parse_float(row[4]),parse_float(row[5]),parse_float(row[6]),parse_float(row[7]),parse_float(row[8]),parse_float(row[9]),parse_float(row[10]),parse_float(row[11]))
            loc.append(c)
    
    return loc

# %%
CompleteCountry = NamedTuple("CompleteCountry",[('name',str),
                                                ('iso_code',str),
                                                ('date',str),
                                                ('total_vaccinations',float),
                                                ('people_vaccinated',float),
                                                ('people_fully_vaccinated',float),
                                                ('daily_vaccinations_raw',float),
                                                ('daily_vaccinations',float),
                                                ('total_vaccinations_per_hundred',float),
                                                ('people_vaccinated_per_hundred',float),
                                                ('people_fully_vaccinated_per_hundred',float),
                                                ('daily_vaccinations_per_million',float)])
#interp. contry's name, iso code, date, total vaccinations, people fully vaccinated, daily vaccinations raw, daily vaccinations, total vaccinations per hundred, people vaccinated per hundred, people fully vaccinated per hundred, daily vaccinations per million
CAfghanistan = CompleteCountry("Afghanistan","AFG","2021-07-24",1171064.0,861336.0,0,0,13476.0,3.01,2.21,0,346.0)
CAndorra = CompleteCountry("Andorra","AND","2021-01-25",576.0,576.0,0,0,0,0.75,0.75,0,0)
CEgypt = CompleteCountry("Egypt","EGY","2021-07-26",5337506.0,3697974.0,1639532.0,32805.0,21064.0,5.22,3.61,1.6,206.0)
CChad = CompleteCountry("Chad","TCD","2021-07-20",0,0,0,0,660.0,0,0,0,40.0)
CChile = CompleteCountry("Chile","CHL","2021-07-24",25337393.0,13772232.0,12068193.0,33269.0,81523.0,132.54,72.04,63.13,4265.0)
CChina = CompleteCountry("China","CHN","2021-07-26",1565872000.0,0,0,15604000.0,14079429.0,108.79,0,0,9782.0)
CUnitedKingdom = CompleteCountry("United Kingdom","GBR","2021-07-25",83876595.0,46589211.0,37287384.0,142507.0,208976.0,123.56,68.63,54.93,3078.0)
CUnitedStates = CompleteCountry("United States","USA","2021-07-26",342212051.0,188729282.0,163173366.0,393083.0,566374.0,102.32,56.43,48.79,1693.0)
CZimbabwe = CompleteCountry("Zimbabwe","ZWE","2021-07-25",2127402.0,1447342.0,680060.0,10738.0,48838.0,14.31,9.74,4.58,3286.0)

@typecheck
#template based on compound(12 fields)
def fn_for_complete_country(cc: CompleteCountry)->...:
    return ...,(cc.name,
                cc.iso_code,
                cc.date,
                cc.total_vaccinations,
                cc.people_vaccinated,
                cc.people_fully_vaccinated,
                cc.daily_vaccinations_raw,
                cc.daily_vaccinations,
                cc.total_vaccinations_per_hundred,
                cc.people_vaccinated_per_hundred,
                cc.people_fully_vaccinated_per_hundred,
                cc.daily_vaccinations_per_million)

# List[CompleteCountry]
# interp. a list of Country with complete data

LOCC0 = []
LOCC1 = [CAfghanistan,CAndorra,CEgypt]
LOCC2 = [CChad,CChile]
LOCC3 = [CChina,CUnitedKingdom,CUnitedStates,CZimbabwe]

@typecheck
#template based on arbitrary-sized, and the reference rule
def fn_for_locc(locc: List[CompleteCountry]) -> ...:
    #description for accumulator
    acc = ... #type:...
    for cc in locc:
        acc = ...,(fn_for_complete_country(cc),acc)
    return ...,(acc)

# %%
@typecheck
def country_with_compl_data(loc:List[Country]) -> List[CompleteCountry]:
    """
    enter a list of Country, return a list of Country with complete data(None->0)
    """
    #return []
    #template from List[Country]
    #template based on arbitrary-sized, and the reference rule
    #acc contains the list of Country with complete data(None->0)
    acc = [] #type:list
    for c in loc:
        fna = total_vaccinations(c.total_vaccinations)
        fnb = people_vaccinated(c.people_vaccinated)
        fnc = people_fully_vaccinated(c.people_fully_vaccinated)
        fnd = daily_vaccinations_raw(c.daily_vaccinations_raw)
        fne = daily_vaccinations(c.daily_vaccinations)
        fnf = total_vaccinations_per_hundred(c.total_vaccinations_per_hundred)
        fng = people_vaccinated_per_hundred(c.people_vaccinated_per_hundred)
        fnh = people_fully_vaccinated_per_hundred(c.people_fully_vaccinated_per_hundred)
        fni = daily_vaccinations_per_million(c.daily_vaccinations_per_million)
        ccountry = CompleteCountry(c.name,c.iso_code,c.date,fna,fnb,fnc,fnd,fne,fnf,fng,fnh,fni)
        acc.append(ccountry)
    return acc

start_testing()
expect(country_with_compl_data(LOC1),LOCC1)
expect(country_with_compl_data(LOC2),LOCC2)
expect(country_with_compl_data(LOC3),LOCC3)

summary()
# Out:
# 3 of 3 tests passed

# %% [markdown]
# # Helper Functions

# %%
#These ten countries have been chosen based on total population:
#(data from: https://worldpopulationreview.com/countries
# data source: United Nation)
# the ten country have the largest population in the world
#["China","India","United States","Indonesia","Pakistan","Brazil","Nigeria","Bangladesh","Russia","Mexico"]

@typecheck
def read_specific_country1(cc:CompleteCountry)->bool:
    """
    enter a country,return if it's data of that country
    """
    #return True
    #template from CompleteCountry
    return cc.name == "China"

start_testing()
expect(read_specific_country1(CAfghanistan),False)
expect(read_specific_country1(CEgypt),False)
expect(read_specific_country1(CChina),True)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def read_specific_country2(cc:CompleteCountry)->bool:
    """
    enter a country,return if it's data of that country
    """
    #return True
    #template from CompleteCountry
    return cc.name == "India"

start_testing()
expect(read_specific_country2(CAfghanistan),False)
expect(read_specific_country2(CEgypt),False)
expect(read_specific_country2(CChina),False)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def read_specific_country3(cc:CompleteCountry)->bool:
    """
    enter a country,return if it's data of that country
    """
    #return True
    #template from CompleteCountry
    return cc.name == "United States"

start_testing()
expect(read_specific_country3(CAfghanistan),False)
expect(read_specific_country3(CUnitedStates),True)
expect(read_specific_country3(CChina),False)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def read_specific_country4(cc:CompleteCountry)->bool:
    """
    enter a country,return if it's data of that country
    """
    #return True
    #template from CompleteCountry
    return cc.name == "Indonesia"

start_testing()
expect(read_specific_country4(CAfghanistan),False)
expect(read_specific_country4(CUnitedStates),False)
expect(read_specific_country4(CChina),False)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def read_specific_country5(cc:CompleteCountry)->bool:
    """
    enter a country,return if it's data of that country
    """
    #return True
    #template from CompleteCountry
    return cc.name == "Pakistan"

start_testing()
expect(read_specific_country5(CAfghanistan),False)
expect(read_specific_country5(CUnitedStates),False)
expect(read_specific_country5(CChina),False)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def read_specific_country6(cc:CompleteCountry)->bool:
    """
    enter a country,return if it's data of that country
    """
    #return True
    #template from CompleteCountry
    return cc.name == "Brazil"

start_testing()
expect(read_specific_country6(CAfghanistan),False)
expect(read_specific_country6(CUnitedStates),False)
expect(read_specific_country6(CChina),False)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def read_specific_country7(cc:CompleteCountry)->bool:
    """
    enter a country,return if it's data of that country
    """
    #return True
    #template from CompleteCountry
    return cc.name == "Nigeria"

start_testing()
expect(read_specific_country7(CAfghanistan),False)
expect(read_specific_country7(CUnitedStates),False)
expect(read_specific_country7(CChina),False)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def read_specific_country8(cc:CompleteCountry)->bool:
    """
    enter a country,return if it's data of that country
    """
    #return True
    #template from CompleteCountry
    return cc.name == "Bangladesh"

start_testing()
expect(read_specific_country8(CAfghanistan),False)
expect(read_specific_country8(CUnitedStates),False)
expect(read_specific_country8(CChina),False)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def read_specific_country9(cc:CompleteCountry)->bool:
    """
    enter a country,return if it's data of that country
    """
    #return True
    #template from CompleteCountry
    return cc.name == "Russia"

start_testing()
expect(read_specific_country5(CAfghanistan),False)
expect(read_specific_country5(CUnitedStates),False)
expect(read_specific_country5(CChina),False)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def read_specific_country10(cc:CompleteCountry)->bool:
    """
    enter a country,return if it's data of that country
    """
    #return True
    #template from CompleteCountry
    return cc.name == "Mexico"

start_testing()
expect(read_specific_country5(CAfghanistan),False)
expect(read_specific_country5(CUnitedStates),False)
expect(read_specific_country5(CChina),False)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def list_china(locc:List[CompleteCountry])->List[CompleteCountry]:
    """
    enter a list of CompleteCountry, return a list of a specific country
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data of a specific country
    chi = [] #type:list
    for cc in locc:
        if read_specific_country1(cc):
            chi.append(cc)
    return chi

# %%
@typecheck
def list_ind(locc:List[CompleteCountry])->List[CompleteCountry]:
    """
    enter a list of CompleteCountry, return a list of a specific country
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data of a specific country
    ind = [] #type:list
    for cc in locc:
        if read_specific_country2(cc):
            ind.append(cc)
    return ind

# %%
@typecheck
def list_usa(locc:List[CompleteCountry])->List[CompleteCountry]:
    """
    enter a list of CompleteCountry, return a list of a specific country
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data of a specific country
    usa = [] #type:list
    for cc in locc:
        if read_specific_country3(cc):
            usa.append(cc)
    return usa

# %%
@typecheck
def list_indo(locc:List[CompleteCountry])->List[CompleteCountry]:
    """
    enter a list of CompleteCountry, return a list of a specific country
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data of a specific country
    indo = [] #type:list
    for cc in locc:
        if read_specific_country4(cc):
            indo.append(cc)
    return indo

# %%
@typecheck
def list_pak(locc:List[CompleteCountry])->List[CompleteCountry]:
    """
    enter a list of CompleteCountry, return a list of a specific country
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data of a specific country
    pak = [] #type:list
    for cc in locc:
        if read_specific_country5(cc):
            pak.append(cc)
    return pak

# %%
@typecheck
def list_bra(locc:List[CompleteCountry])->List[CompleteCountry]:
    """
    enter a list of CompleteCountry, return a list of a specific country
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data of a specific country
    bra = [] #type:list
    for cc in locc:
        if read_specific_country6(cc):
            bra.append(cc)
    return bra

# %%
@typecheck
def list_nig(locc:List[CompleteCountry])->List[CompleteCountry]:
    """
    enter a list of CompleteCountry, return a list of a specific country
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data of a specific country
    nig = [] #type:list
    for cc in locc:
        if read_specific_country7(cc):
            nig.append(cc)
    return nig

# %%
@typecheck
def list_ban(locc:List[CompleteCountry])->List[CompleteCountry]:
    """
    enter a list of CompleteCountry, return a list of a specific country
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data of a specific country
    ban = [] #type:list
    for cc in locc:
        if read_specific_country8(cc):
            ban.append(cc)
    return ban

# %%
@typecheck
def list_rus(locc:List[CompleteCountry])->List[CompleteCountry]:
    """
    enter a list of CompleteCountry, return a list of a specific country
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data of a specific country
    rus = [] #type:list
    for cc in locc:
        if read_specific_country9(cc):
            rus.append(cc)
    return rus

# %%
@typecheck
def list_mex(locc:List[CompleteCountry])->List[CompleteCountry]:
    """
    enter a list of CompleteCountry, return a list of a specific country
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data of a specific country
    mex = [] #type:list
    for cc in locc:
        if read_specific_country10(cc):
            mex.append(cc)
    return mex

# %%
@typecheck
def january(cc:CompleteCountry)->bool:
    """
    enter a country, return if it's a data of January 2021
    """
    #return True
    #template from CompleteCountry
    return int(cc.date[6]) == 1
start_testing()
expect(january(CAfghanistan),False)
expect(january(CAndorra),True)
expect(january(CEgypt),False)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def february(cc:CompleteCountry)->bool:
    """
    enter a country, return if it's a data of February 2021
    """
    #return True
    #template from CompleteCountry
    return int(cc.date[6]) == 2
start_testing()
expect(february(CAfghanistan),False)
expect(february(CEgypt),False)
expect(february(CChad),False)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def march(cc:CompleteCountry)->bool:
    """
    enter a country, return if it's a data of March 2021
    """
    #return True
    #template from CompleteCountry
    return int(cc.date[6]) == 3
start_testing()
expect(march(CAfghanistan),False)
expect(march(CAndorra),False)
expect(march(CUnitedKingdom),False)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def april(cc:CompleteCountry)->bool:
    """
    enter a country, return if it's a data of April 2021
    """
    #return True
    #template from CompleteCountry
    return int(cc.date[6]) == 4

start_testing()
expect(april(CAndorra),False)
expect(april(CChina),False)
expect(april(CChad),False)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def may(cc:CompleteCountry)->bool:
    """
    enter a country, return if it's a data of May 2021
    """
    #return True
    #template from CompleteCountry
    return int(cc.date[6]) == 5

start_testing()
expect(may(CAndorra),False)
expect(may(CZimbabwe),False)
expect(may(CEgypt),False)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def june(cc:CompleteCountry)->bool:
    """
    enter a country, return if it's a data of June 2021
    """
    #return True
    #template from CompleteCountry
    return int(cc.date[6]) == 6

start_testing()
expect(june(CAndorra),False)
expect(june(CZimbabwe),False)
expect(june(CEgypt),False)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def july(cc:CompleteCountry)->bool:
    """
    enter a country, return if it's a data of July 2021
    """
    #return True
    #template from CompleteCountry
    return int(cc.date[6]) == 7

start_testing()
expect(july(CAndorra),False)
expect(july(CChad),True)
expect(july(CUnitedKingdom),True)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def list_total_vac(cc:CompleteCountry)->float:
    """
    enter a country,return cc.total_vaccinations
    """
    #return 0.0
    #template from CompleteCountry
    return cc.total_vaccinations
start_testing()
expect(list_total_vac(CUnitedKingdom),83876595.0)
expect(list_total_vac(CUnitedStates),342212051.0)
expect(list_total_vac(CEgypt),5337506.0)

summary()
# Out:
# 3 of 3 tests passed

# %%
@typecheck
def total_vaccinations1(locc:List[CompleteCountry])->float:
    """
    enter a list of CompleteCountry, return total vaccinations of that month
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data about cc.total_vaccinations of a specific country
    tv = 0#type:float
    for cc in locc:
        if january(cc):
            tv = tv + list_total_vac(cc)
    return tv

# %%
@typecheck
def total_vaccinations2(locc:List[CompleteCountry])->float:
    """
    enter a list of CompleteCountry, return total vaccinations of that month
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data about cc.total_vaccinations of a specific country
    tv = 0 #type:float
    for cc in locc:
        if february(cc):
            tv = tv + list_total_vac(cc)
    return tv

# %%
@typecheck
def total_vaccinations3(locc:List[CompleteCountry])->float:
    """
    enter a list of CompleteCountry, return total vaccinations of that month
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data about cc.total_vaccinations of a specific country
    tv = 0 #type:float
    for cc in locc:
        if march(cc):
            tv = tv + list_total_vac(cc)
    return tv

# %%
@typecheck
def total_vaccinations4(locc:List[CompleteCountry])->float:
    """
    enter a list of CompleteCountry, return total vaccinations of that month
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data about cc.total_vaccinations of a specific country
    tv = 0 #type:float
    for cc in locc:
        if april(cc):
            tv = tv + list_total_vac(cc)
    return tv

# %%
@typecheck
def total_vaccinations5(locc:List[CompleteCountry])->float:
    """
    enter a list of CompleteCountry, return total vaccinations of that month
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data about cc.total_vaccinations of a specific country
    tv = 0 #type:float
    for cc in locc:
        if may(cc):
            tv = tv + list_total_vac(cc)
    return tv

# %%
@typecheck
def total_vaccinations6(locc:List[CompleteCountry])->float:
    """
    enter a list of CompleteCountry, return total vaccinations of that month
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data about cc.total_vaccinations of a specific country
    tv = 0 #type:float
    for cc in locc:
        if june(cc):
            tv = tv + list_total_vac(cc)
    return tv

# %%
@typecheck
def total_vaccinations7(locc:List[CompleteCountry])->float:
    """
    enter a list of CompleteCountry, return total vaccinations of that month
    """
    #return []
    #template from List[CompleteCountry]
    #template based on arbitrary-sized, and the reference rule
    #acc contains all data about cc.total_vaccinations of a specific country
    tv = 0 #type:float
    for cc in locc:
        if july(cc):
            tv = tv + list_total_vac(cc)
    return tv

# %% [markdown]
# # Analyze & Main Functions

# %%
import matplotlib.pyplot as plt
import numpy as np

@typecheck
def draw_line_chart1(loc:List[Country])->None:
    """
    display a line chart showing the total vaccinations recieved every month in five specific countries:
    China,India,United States,Indonesia and Pakistan
    """
    x = np.array(["January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021"])
    y1 = np.array([total_vaccinations1(list_china((country_with_compl_data(loc)))),
                   total_vaccinations2(list_china((country_with_compl_data(loc)))),
                   total_vaccinations3(list_china((country_with_compl_data(loc)))),
                   total_vaccinations4(list_china((country_with_compl_data(loc)))),
                   total_vaccinations5(list_china((country_with_compl_data(loc)))),
                   total_vaccinations6(list_china((country_with_compl_data(loc)))),
                   total_vaccinations7(list_china((country_with_compl_data(loc))))])

    y2 = np.array([total_vaccinations1(list_ind((country_with_compl_data(loc)))),
                   total_vaccinations2(list_ind((country_with_compl_data(loc)))),
                   total_vaccinations3(list_ind((country_with_compl_data(loc)))),
                   total_vaccinations4(list_ind((country_with_compl_data(loc)))),
                   total_vaccinations5(list_ind((country_with_compl_data(loc)))),
                   total_vaccinations6(list_ind((country_with_compl_data(loc)))),
                   total_vaccinations7(list_ind((country_with_compl_data(loc))))])

    y3 = np.array([total_vaccinations1(list_usa((country_with_compl_data(loc)))),
                   total_vaccinations2(list_usa((country_with_compl_data(loc)))),
                   total_vaccinations3(list_usa((country_with_compl_data(loc)))),
                   total_vaccinations4(list_usa((country_with_compl_data(loc)))),
                   total_vaccinations5(list_usa((country_with_compl_data(loc)))),
                   total_vaccinations6(list_usa((country_with_compl_data(loc)))),
                   total_vaccinations7(list_usa((country_with_compl_data(loc))))])
    
    y4 = np.array([total_vaccinations1(list_indo((country_with_compl_data(loc)))),
                   total_vaccinations2(list_indo((country_with_compl_data(loc)))),
                   total_vaccinations3(list_indo((country_with_compl_data(loc)))),
                   total_vaccinations4(list_indo((country_with_compl_data(loc)))),
                   total_vaccinations5(list_indo((country_with_compl_data(loc)))),
                   total_vaccinations6(list_indo((country_with_compl_data(loc)))),
                   total_vaccinations7(list_indo((country_with_compl_data(loc))))])

    y5 = np.array([total_vaccinations1(list_pak((country_with_compl_data(loc)))),
                   total_vaccinations2(list_pak((country_with_compl_data(loc)))),
                   total_vaccinations3(list_pak((country_with_compl_data(loc)))),
                   total_vaccinations4(list_pak((country_with_compl_data(loc)))),
                   total_vaccinations5(list_pak((country_with_compl_data(loc)))),
                   total_vaccinations6(list_pak((country_with_compl_data(loc)))),
                   total_vaccinations7(list_pak((country_with_compl_data(loc))))])
    
    plt.plot(x,y1,x,y2,x,y3,x,y4,x,y5)
    
    font1 = {'size':15}
    font2 = {'size':12}
    
    plt.xticks(x, rotation ='vertical')
    plt.xlabel('Month', fontdict = font2)
    plt.ylabel('Total Vaccinations', fontdict = font2)
    
    font1 = {'size':15}
    
    plt.title('Total Vaccinations against Covid-19, July,2021', fontdict = font1, pad = 20)
    plt.legend(["China","India","United States","Indonesia","Pakistan"], loc = 'upper right', borderaxespad = -12)
    plt.show() 
    return

# %%
@typecheck
def draw_line_chart2(loc:List[Country])->None:
    """
    display a line chart showing the total vaccinations recieved every month in five specific countries:
    Brazil,Nigeria,Bangladesh,Russia,Mexico
    """
    x = np.array(["January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021"])
    y1 = np.array([total_vaccinations1(list_bra((country_with_compl_data(loc)))),
                   total_vaccinations2(list_bra((country_with_compl_data(loc)))),
                   total_vaccinations3(list_bra((country_with_compl_data(loc)))),
                   total_vaccinations4(list_bra((country_with_compl_data(loc)))),
                   total_vaccinations5(list_bra((country_with_compl_data(loc)))),
                   total_vaccinations6(list_bra((country_with_compl_data(loc)))),
                   total_vaccinations7(list_bra((country_with_compl_data(loc))))])
    
    y2 = np.array([total_vaccinations1(list_nig((country_with_compl_data(loc)))),
                   total_vaccinations2(list_nig((country_with_compl_data(loc)))),
                   total_vaccinations3(list_nig((country_with_compl_data(loc)))),
                   total_vaccinations4(list_nig((country_with_compl_data(loc)))),
                   total_vaccinations5(list_nig((country_with_compl_data(loc)))),
                   total_vaccinations6(list_nig((country_with_compl_data(loc)))),
                   total_vaccinations7(list_nig((country_with_compl_data(loc))))])

    y3 = np.array([total_vaccinations1(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations2(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations3(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations4(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations5(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations6(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations7(list_ban((country_with_compl_data(loc))))])

    y4 = np.array([total_vaccinations1(list_rus((country_with_compl_data(loc)))),
                   total_vaccinations2(list_rus((country_with_compl_data(loc)))),
                   total_vaccinations3(list_rus((country_with_compl_data(loc)))),
                   total_vaccinations4(list_rus((country_with_compl_data(loc)))),
                   total_vaccinations5(list_rus((country_with_compl_data(loc)))),
                   total_vaccinations6(list_rus((country_with_compl_data(loc)))),
                   total_vaccinations7(list_rus((country_with_compl_data(loc))))])
    
    y5 = np.array([total_vaccinations1(list_mex((country_with_compl_data(loc)))),
                   total_vaccinations2(list_mex((country_with_compl_data(loc)))),
                   total_vaccinations3(list_mex((country_with_compl_data(loc)))),
                   total_vaccinations4(list_mex((country_with_compl_data(loc)))),
                   total_vaccinations5(list_mex((country_with_compl_data(loc)))),
                   total_vaccinations6(list_mex((country_with_compl_data(loc)))),
                   total_vaccinations7(list_mex((country_with_compl_data(loc))))])
    
    plt.plot(x, y1,color="#774898")
    plt.plot(x, y2,color="#00A8B5")
    plt.plot(x, y3,color="#E62A76")
    plt.plot(x, y4,color="#FBB901")
    plt.plot(x, y5,color="#F18A9B")
    
    font1 = {'size':15}
    font2 = {'size':12}
    
    plt.xticks(x, rotation = 'vertical')
    plt.xlabel('Month', fontdict = font2)
    plt.ylabel('Total Vaccinations', fontdict = font2)
    plt.title('Total Vaccinations against Covid-19, July,2021', fontdict = font1, pad = 20)
    
    plt.legend(["Brazil","Nigeria","Bangladesh","Russia","Mexico"], loc = 'upper right', borderaxespad = -12)
    
    plt.show() 
    return

# %%
@typecheck
def draw_line_chart3(loc:List[Country])->None:
    """
    display a line chart showing the total vaccinations recieved every month in the world
    """
    x = np.array(["January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021"])
    y = np.array([total_vaccinations1(((country_with_compl_data(loc)))),
                   total_vaccinations2(((country_with_compl_data(loc)))),
                   total_vaccinations3(((country_with_compl_data(loc)))),
                   total_vaccinations4(((country_with_compl_data(loc)))),
                   total_vaccinations5(((country_with_compl_data(loc)))),
                   total_vaccinations6(((country_with_compl_data(loc)))),
                   total_vaccinations7(((country_with_compl_data(loc))))])
    
    plt.plot(x,y,color="#E62A76")
    
    
    font1 = {'size':15}
    font2 = {'size':12}
    
    plt.xticks(x, rotation = 'vertical')
    plt.xlabel('Month', fontdict = font2)
    plt.ylabel('Total Vaccinations', fontdict = font2)
    plt.title('World Total Vaccinations against Covid-19, July,2021', fontdict = font1, pad = 20)
    
    plt.legend(["World"], loc = 'upper right', borderaxespad = -10)
    
    plt.show() 
    return

# %%
@typecheck
def daw_subplots(loc:List[Country])->None:
    """
    display subplots showing the total vaccinations recieved every month in ten specific countries:
    "China","India","United States","Indonesia","Pakistan","Brazil","Nigeria","Bangladesh","Russia","Mexico"   
    """
    #plot 1:
    x = np.array(["January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021"])
    y = np.array([total_vaccinations1(list_china((country_with_compl_data(loc)))),
                  total_vaccinations2(list_china((country_with_compl_data(loc)))),
                  total_vaccinations3(list_china((country_with_compl_data(loc)))),
                  total_vaccinations4(list_china((country_with_compl_data(loc)))),
                  total_vaccinations5(list_china((country_with_compl_data(loc)))),
                  total_vaccinations6(list_china((country_with_compl_data(loc)))),
                  total_vaccinations7(list_china((country_with_compl_data(loc))))])

    plt.subplot(2, 5, 1)
    plt.plot(x,y)
    plt.xticks(x, rotation = 'vertical')
    plt.title("China")

    #plot 2:
    x = np.array(["January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021"])
    y2 = np.array([total_vaccinations1(list_ind((country_with_compl_data(loc)))),
                   total_vaccinations2(list_ind((country_with_compl_data(loc)))),
                   total_vaccinations3(list_ind((country_with_compl_data(loc)))),
                   total_vaccinations4(list_ind((country_with_compl_data(loc)))),
                   total_vaccinations5(list_ind((country_with_compl_data(loc)))),
                   total_vaccinations6(list_ind((country_with_compl_data(loc)))),
                   total_vaccinations7(list_ind((country_with_compl_data(loc))))])

    plt.subplot(2, 5, 2)
    plt.plot(x,y2)
    plt.xticks(x, rotation = 'vertical')
    plt.title("India")
    
    #plot 3
    x = np.array(["January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021"])
    y3 = np.array([total_vaccinations1(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations2(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations3(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations4(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations5(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations6(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations7(list_ban((country_with_compl_data(loc))))])
    
    plt.subplot(2, 5, 3)
    plt.plot(x,y3)
    plt.xticks(x, rotation = 'vertical')
    plt.title("United States")
    
    #plot 4
    x = np.array(["January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021"])
    y4 = np.array([total_vaccinations1(list_indo((country_with_compl_data(loc)))),
                   total_vaccinations2(list_indo((country_with_compl_data(loc)))),
                   total_vaccinations3(list_indo((country_with_compl_data(loc)))),
                   total_vaccinations4(list_indo((country_with_compl_data(loc)))),
                   total_vaccinations5(list_indo((country_with_compl_data(loc)))),
                   total_vaccinations6(list_indo((country_with_compl_data(loc)))),
                   total_vaccinations7(list_indo((country_with_compl_data(loc))))])
    
    plt.subplot(2, 5, 4)
    plt.plot(x,y4)
    plt.xticks(x, rotation = 'vertical')
    plt.title("Indonesia")
    
    #plot 5
    x = np.array(["January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021"])
    y5 = np.array([total_vaccinations1(list_pak((country_with_compl_data(loc)))),
                   total_vaccinations2(list_pak((country_with_compl_data(loc)))),
                   total_vaccinations3(list_pak((country_with_compl_data(loc)))),
                   total_vaccinations4(list_pak((country_with_compl_data(loc)))),
                   total_vaccinations5(list_pak((country_with_compl_data(loc)))),
                   total_vaccinations6(list_pak((country_with_compl_data(loc)))),
                   total_vaccinations7(list_pak((country_with_compl_data(loc))))])
    
    plt.subplot(2, 5, 5)
    plt.plot(x,y5)
    plt.xticks(x, rotation = 'vertical')
    plt.title("Pakistan")
    
    #plot 6
    x = np.array(["January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021"])
    y6 = np.array([total_vaccinations1(list_bra((country_with_compl_data(loc)))),
                   total_vaccinations2(list_bra((country_with_compl_data(loc)))),
                   total_vaccinations3(list_bra((country_with_compl_data(loc)))),
                   total_vaccinations4(list_bra((country_with_compl_data(loc)))),
                   total_vaccinations5(list_bra((country_with_compl_data(loc)))),
                   total_vaccinations6(list_bra((country_with_compl_data(loc)))),
                   total_vaccinations7(list_bra((country_with_compl_data(loc))))])
    
    plt.subplot(2, 5, 6)
    plt.plot(x,y6)
    plt.xticks(x, rotation = 'vertical')
    plt.title("Brazil")
    
    #plot 7
    x = np.array(["January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021"])
    y7 = np.array([total_vaccinations1(list_nig((country_with_compl_data(loc)))),
                   total_vaccinations2(list_nig((country_with_compl_data(loc)))),
                   total_vaccinations3(list_nig((country_with_compl_data(loc)))),
                   total_vaccinations4(list_nig((country_with_compl_data(loc)))),
                   total_vaccinations5(list_nig((country_with_compl_data(loc)))),
                   total_vaccinations6(list_nig((country_with_compl_data(loc)))),
                   total_vaccinations7(list_nig((country_with_compl_data(loc))))])
    
    plt.subplot(2, 5, 7)
    plt.plot(x,y7)
    plt.xticks(x, rotation = 'vertical')
    plt.title("Nigeria")
    
    #plot 8
    x = np.array(["January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021"])
    y8 = np.array([total_vaccinations1(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations2(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations3(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations4(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations5(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations6(list_ban((country_with_compl_data(loc)))),
                   total_vaccinations7(list_ban((country_with_compl_data(loc))))])
    
    plt.subplot(2, 5, 8)
    plt.plot(x,y8)
    plt.xticks(x, rotation = 'vertical')
    plt.title("Bangladesh")
    
    #plot 9
    x = np.array(["January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021"])
    y9 = np.array([total_vaccinations1(list_rus((country_with_compl_data(loc)))),
                   total_vaccinations2(list_rus((country_with_compl_data(loc)))),
                   total_vaccinations3(list_rus((country_with_compl_data(loc)))),
                   total_vaccinations4(list_rus((country_with_compl_data(loc)))),
                   total_vaccinations5(list_rus((country_with_compl_data(loc)))),
                   total_vaccinations6(list_rus((country_with_compl_data(loc)))),
                   total_vaccinations7(list_rus((country_with_compl_data(loc))))])
    
    plt.subplot(2, 5, 9)
    plt.plot(x,y9)
    plt.xticks(x, rotation = 'vertical')
    plt.title("Russia")
    
    #plot 10
    x = np.array(["January 2021","February 2021","March 2021","April 2021","May 2021","June 2021","July 2021"])
    y10 = np.array([total_vaccinations1(list_mex((country_with_compl_data(loc)))),
                   total_vaccinations2(list_mex((country_with_compl_data(loc)))),
                   total_vaccinations3(list_mex((country_with_compl_data(loc)))),
                   total_vaccinations4(list_mex((country_with_compl_data(loc)))),
                   total_vaccinations5(list_mex((country_with_compl_data(loc)))),
                   total_vaccinations6(list_mex((country_with_compl_data(loc)))),
                   total_vaccinations7(list_mex((country_with_compl_data(loc))))])
    
    plt.subplot(2, 5, 10)
    plt.plot(x,y10)
    plt.xticks(x, rotation = 'vertical')
    plt.title("Mexico")
    

    
    plt.subplots_adjust(left=0.1,
                    bottom=0, 
                    right=2, 
                    top=2.5, 
                    wspace=0.5, 
                    hspace=0.5)


    ttl = plt.suptitle('Total Vaccinations against Covid-19, July,2021')
    ttl.set_position([.9,2.8])

    plt.show()
    return

# %%
@typecheck
def main2(filename: str) -> None:
    """
    Reads the file from given filename, analyzes the data,
    returns the result
    """
    # Template from HtDAP, based on composition
    return draw_line_chart1(read(filename))

# %%
@typecheck
def main3(filename: str) -> None:
    """
    Reads the file from given filename, analyzes the data,
    returns the result
    """
    # Template from HtDAP, based on composition
    return draw_line_chart2(read(filename))

# %%
@typecheck
def main4(filename: str) -> None:
    """
    Reads the file from given filename, analyzes the data,
    returns the result
    """
    # Template from HtDAP, based on composition
    return draw_line_chart3(read(filename))

# %%
@typecheck
def main5(filename: str) -> None:
    """
    Reads the file from given filename, analyzes the data,
    returns the result
    """
    # Template from HtDAP, based on composition
    return daw_subplots(read(filename))

# %% [markdown]
# # Show Plots

# %%
main2('country_vaccinations.csv')

# %%
main3('country_vaccinations.csv')

# %%
main4('country_vaccinations.csv')

# %%
main5('country_vaccinations.csv')

# %%
start_testing()

# Examples and tests for main2
expect(main2('country_vaccinations.csv'),None)

# Examples and tests for main3
expect(main3('country_vaccinations.csv'),None)

# Examples and tests for main4
expect(main4('country_vaccinations.csv'),None)

# Examples and tests for main5
expect(main5('country_vaccinations.csv'),None)

# Examples and tests for read
expect(read('country_vaccinations-test1.csv'),[Afghanistan,Andorra,Egypt])
expect(read('country_vaccinations-test2.csv'),[Chad,Chile])
expect(read('country_vaccinations-test3.csv'),[China,UnitedKingdom,UnitedStates,Zimbabwe])

# Examples and tests for analyze2
expect(total_vaccinations1(country_with_compl_data(read('country_vaccinations.csv'))),1151372030.0)
expect(total_vaccinations2(country_with_compl_data(read('country_vaccinations.csv'))),4196632427.0)
expect(total_vaccinations3(country_with_compl_data(read('country_vaccinations.csv'))),11717802961.0)
expect(total_vaccinations4(country_with_compl_data(read('country_vaccinations.csv'))),25665336848.0)
expect(total_vaccinations5(country_with_compl_data(read('country_vaccinations.csv'))),45271214302.0)
expect(total_vaccinations6(country_with_compl_data(read('country_vaccinations.csv'))),73845322899.0)
expect(total_vaccinations7(country_with_compl_data(read('country_vaccinations.csv'))),87625314576.0)
summary()
# Out:
# 14 of 14 tests passed
